# %%
import numpy as np
import pandas as pd
import selenium
from selenium.webdriver.common.keys import Keys
import matplotlib.pyplot as plt
import time
import os
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver

# %% [markdown]
# Question 1: Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
driver.maximize_window()

# %%
details=[]

for i in driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td"):
    details.append(i.text)
    
details=details[:180]

driver.close()
rank=[]
name=[]
artist=[]
views=[]
upload_date=[]
i=0

while i<len(details):
    rank.append(details[i])
    i+=1
    name.append(details[i])
    i+=1
    artist.append(details[i])
    i+=1
    views.append(details[i])
    i+=1
    upload_date.append(details[i])
    i+=2

# %%
YT=pd.DataFrame({"Rank":rank,
                "Name":name,
                "UPLOAD_DATE":upload_date,
                "VIEWS IN MILLION":views})
YT
# Out:
#    Rank                                             Name        UPLOAD_DATE  \
# 0    1.                           "Baby Shark Dance"[23]      June 17, 2016
# 1    2.                                  "Despacito"[25]   January 12, 2017
# 2    3.                       "Johny Johny Yes Papa"[26]    October 8, 2016
# 3    4.                               "Shape of You"[27]   January 30, 2017
# 4    5.                              "See You Again"[28]      April 6, 2015
# 5    6.                                  "Bath Song"[31]        May 2, 2018
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[32]  February 27, 2018
# 7    8.   "Masha and the Bear – Recipe for Disaster"[33]   January 31, 2012
# 8    9.                                "Uptown Funk"[34]  November 19, 2014
# 9   10.                "Phonics Song with Two Words"[35]      March 6, 2014
# 10  11.                              "Gangnam Style"[36]      July 15, 2012
# ...

# %% [markdown]
# Question 2: Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://www.bcci.tv/')
driver.maximize_window()

btn=driver.find_element_by_xpath("//div[@class = 'navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
driver.get(btn.get_attribute("href"))

# %%
match_title=[]
series=[]
place=[]
date=[]
time=[]
datetime=[]
for i in driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__format']"):
    match_title.append(i.text)
    
for i in driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[@class='u-unskewed-text fixture__tournament-label u-truncated']"):
    series.append(i.text)

for i in driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']/p/span"):
    place.append(i.text)
    
for i in driver.find_elements_by_xpath("//div[@class='fixture__datetime desktop-only']"):
    datetime.append(i.text.replace('\n',' '))
    
driver.close()

date=[i.split(' ',3)[:3] for i in datetime]
date=[' '.join(i) for i in date]
time=[i.split(' ',3)[-1] for i in datetime]

# %%
matches_data=pd.DataFrame({'match title':match_title,
                          "series":series,
                          "place":place,
                          "date":date,
                          "time":time})
matches_data
# Out:
#    match title                          series  \
# 0         T20I    2021 ICC MEN'S T20 WORLD CUP
# 1         T20I    2021 ICC MEN'S T20 WORLD CUP
# 2         T20I    2021 ICC MEN'S T20 WORLD CUP
# 3         T20I    2021 ICC MEN'S T20 WORLD CUP
# 4         T20I    2021 ICC MEN'S T20 WORLD CUP
# 5         T20I        INDIA V NEW ZEALAND 2021
# 6         T20I        INDIA V NEW ZEALAND 2021
# 7         T20I        INDIA V NEW ZEALAND 2021
# 8         TEST        INDIA V NEW ZEALAND 2021
# 9         TEST        INDIA V NEW ZEALAND 2021
# 10        TEST  SOUTH AFRICA V INDIA 2021/2022
# 11        TEST  SOUTH AFRICA V INDIA 2021/2022
# 12        TEST  SOUTH AFRICA V INDIA 2021/2022
# 13         ODI  SOUTH AFRICA V INDIA 2021/2022
# 14         ODI  SOUTH AFRICA V INDIA 2021/2022
# 15         ODI  SOUTH AFRICA V INDIA 2021/2022
# 16        T20I  SOUTH AFRICA V INDIA 2021/2022
# 17        T20I  SOUTH AFRICA V INDIA 2021/2022
# 18        T20I  SOUTH AFRICA V INDIA 2021/2022
# ...

# %% [markdown]
# Question 3: Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://www.guru99.com/exception-handling-selenium.html')
driver.maximize_window()

# %%
details=[]

for i in driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td"):
    details.append(i.text)

driver.close()
name=[]
description=[]
i=0

while i<len(details):
    name.append(details[i])
    i+=1
    description.append(details[i])
    i+=1

# %%
Exceptions=pd.DataFrame({"Name":name,
                "Description":description})
Exceptions
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# Question 4: Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)

# %%
def State_wise_GDP():
    """Creating function that searches details of India State_wise_GDP"""
    
    template = 'http://statisticstimes.com/'#URL template for accessing the website.
    driver = webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe") #Calling the Web Driver.
    driver.get(template) #Opening with the URL template.
    driver.maximize_window() #Maximize the Window.
    
    href = [] #Declaring the list href to scrap all the href details
    for i in driver.find_elements_by_xpath("//div [@class = 'dropdown']/div [@class = 'dropdown-content']/a"):
        href.append(i.get_attribute('href'))
        
    driver.get(href[4]) #opening the href[4] which is GDP of India.
    
    href = [] #Declaring the list href to scrap all the href details of GDP of Indian states.
    for i in driver.find_elements_by_xpath("//div [@style = 'float:left;background-color:seashell;width:400px;height:800px;']/ul [@style = 'list-style-type:none;margin-left:20px;']/li/a"):
        if i.text == '» GDP of Indian states':
            href.append(i.get_attribute('href'))
    
    driver.get(href[0]) #opening the href[4] which is GDP of Indian states.
    
    Rank = [] #Declaring Rank list to collect the Rank details
    State = [] #Declaring State list to collect the State details
    GSDP20 = [] #Declaring GSDP20 list to collect the GSDP20 details
    GSDP19 = [] #Declaring GSDP19 list to collect the GSDP19 details
    Share = [] #Declaring Share list to collect the Share details
    GDP = [] #Declaring GDP list to collect the GDP details

    details = [] #scraping all the above mentioned details and storing it in the details list.
    for i in driver.find_elements_by_xpath("//tbody /tr [@role = 'row']/td"):
        details.append(i.text)
    
    driver.close() #Exiting the Driver post collecting all the details.
    
    details = details[:264] #Sorting the list with the required details.
    
    z= 0
    while z < len(details): # Splitting the collected details and storing it in the required list.
        Rank.append(details[z])
        z+=1
        State.append(details[z])
        z+=1
        GSDP20.append(details[z])
        z+=1
        GSDP19.append(details[z])
        z+=1
        Share.append(details[z])
        z+=1
        GDP.append(details[z])
        z+=3
    
    #Creating a DataFrame with collected details.
    table = pd.DataFrame({"Rank" : Rank,
                          "State" : State,
                          "GSDP(19-20)" : GSDP20,
                          "GSDP(18-19)" : GSDP19,
                          "Share(2018)" : Share,
                          "GDP($ billion)": GDP})
    
    return table #returing the dataframe.

# %%
GDP = State_wise_GDP() #Calling the function and storing it in a variable.
GDP.head(10)
# Out:
#   Rank           State GSDP(19-20) GSDP(18-19) Share(2018) GDP($ billion)
# 0    1     Maharashtra           -   2,632,792      13.94%        399.921
# 1    2      Tamil Nadu   1,845,853   1,630,208       8.63%        247.629
# 2    3   Uttar Pradesh   1,687,818   1,584,764       8.39%        240.726
# 3    4         Gujarat           -   1,502,899       7.96%        228.290
# 4    5       Karnataka   1,631,977   1,493,127       7.91%        226.806
# 5    6     West Bengal   1,253,832   1,089,898       5.77%        165.556
# 6    7       Rajasthan   1,020,989     942,586       4.99%        143.179
# 7    8  Andhra Pradesh     972,782     862,957       4.57%        131.083
# 8    9       Telangana     969,604     861,031       4.56%        130.791
# 9   10  Madhya Pradesh     906,672     809,592       4.29%        122.977

# %% [markdown]
# Question 5: Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://github.com/')
driver.maximize_window()

button=driver.find_element_by_xpath("//ul [@class= 'list-style-none mb-3']/li [@class = 'edge-item-fix']/a [@data-ga-click = '(Logged out) Header, go to Trending']")
driver.get(button.get_attribute('href'))
href=[]
for i in driver.find_elements_by_xpath("//h1 [@class = 'h3 lh-condensed']/a"):
    href.append(i.get_attribute('href'))
    
driver.close()

Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

for i in href:
    driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
    driver.get(i)
    driver.maximize_window()
    
    tit=driver.find_element_by_xpath("//h1 [@class = ' d-flex flex-wrap flex-items-center wb-break-word f3 text-normal']")
    Repository_title.append(tit.text.replace('\n',' '))
    
    try:
        des=driver.find_element_by_xpath("//div [@class = 'BorderGrid-cell']/p [@class = 'f4 mt-3']")
        Repository_description.append(des.text)
    except:
        Repository_description.append("-")
    count=[]
    try:
        for i in driver.find_elements_by_xpath("//span[@class ='Counter']"):
            count.append(i.get_attribute('title'))
            Contributors_count.append(count[-1])
    except:
        Contributors_count.append('1')
       
    lang = [] #Creating a Dummy Variable to collect the appropriate Language_used details.
    for i in driver.find_elements_by_xpath("//ul [@class = 'list-style-none']/li [@class = 'd-inline']//span"):
        lang.append(i.text)
    if (" ".join(lang)) == '':
        Language_used.append('-')
    else:
        Language_used.append(" ".join(lang))
        
    driver.close()

# %%
github=pd.DataFrame({
    "Repository_Title":Repository_title,
    "Repository_description":Repository_description,
    "Contributors_count":Contributors_count[:25],
    "Language_used":Language_used
})
github

# %% [markdown]
# Question 6: Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://www.billboard.com/')
driver.maximize_window()

href=[]
for i in driver.find_elements_by_xpath("//li [@class='header__subnav_item']/a"):
    if i.text=='HOT 100':
        href.append(i.get_attribute('href'))
driver.get(href[0])

Song_name=[i.text for i in driver.find_elements_by_xpath("//span[@class='cahrt-element__information__song text--truncate color--primary']")]

Artist_name=[i.text for i in driver.find_elements_by_xpath("//span[@ class='chart-element__information__artist text--truncate color--secondary']")]

Last_week_rank=[i.text for i in driver.find_elemens_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")]

Peak_rank=[i.text for i in driver.find_elements_by_xpath("//div[@class='chart-element__metas chart-element__metas--large display--flex flex--y-center']/div[@class='chart-element__meta text--center color--secondary text--peak']")]

Weeks_on_bord=[i.text for i in driver.find_elements_bY_xpath("//div[@class='chart-element__metas chart-element__metas--large display--flex flex--y-center]/div[@class='chart-element__meta text--center color--secondary text--week']")]

driver.close()

# %% [markdown]
# Question 7: Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://www.naukri.com/')
driver.maximize_window()

Recruiters=driver.find_element_by_xpath("//li/a[@title='Search Recruiters']")
href=Recruiters.get_attribute('href')
driver.get(href)

search=driver.find_element_by_xpath("//div[@class='inpWrap']/input")
search.send_keys("Data science")

search_btn=driver.find_element_by_id("qsbFormBtn")
search_btn.click()

# %%
Name=[i.text for i in driver.find_elements_by_xpath("//a[@class='ellipsis']/span")]
company=[i.text for i in driver.find_elements_by_xpath("//i[@class='cmpIcn']")]
Designation=[i.text for i in driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='ellipsis clr']")]
skills=[i.text for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")]

loc=[]
try:
    location=driver.find_elements_by_xpath("//p[@class='highlightable']//small[@class='ellipsis']")
    for i in location:
        loc.append(i.text)
except NoSuchElementException:
    loc.append('-')

# %%
len(Name)
# Out:
# 50

# %%
len(loc)
# Out:
# 49

# %%
Naukri=pd.DataFrame({"Name":Name,
                    "Company":company,
                    "Designation":Designation,
                    "skills":skills})
Naukri
# Out:
#                                              Name Company  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                       Narasimha
# 5                                    subhas patel
# 6    Abhishek - Only Analytics Hiring - India and
# 7   Institute for Financial Management and Resear
# 8                                     Balu Ramesh
# 9                                   Asif Lucknowi
# 10                                InstaFinancials
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                    Ruchi Dhote
# 16                             Mahesh Babu Channa
# 17                                   Kapil Devang
# ...

# %% [markdown]
# Question 8: Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
driver.maximize_window()

details=[i.text for i in driver.find_elements_by_xpath("//table [@class='in-article sortable']//tr/td")]
driver.close()
details.remove('SOURCE: NIELSEN BOOK SCAN')
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]
j=0
while j<len(details):
    j+=1
    Book_name.append(details[j])
    j+=1
    Author_name.append(details[j])
    j+=1
    Volumes_sold.append(details[j])
    j+=1
    Publisher.append(details[j])
    j+=1
    Genre.append(details[j])
    j+=1

# %%
book_data=pd.DataFrame({"NAME":Book_name,
                       "AUTHOR":Author_name,
                       "VOLUME_SOLD":Volumes_sold,
                       "PUBLISHER":Publisher,
                       "GENRE":Genre})
book_data
# Out:
#                                                  NAME            AUTHOR  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    VOLUME_SOLD        PUBLISHER                        GENRE
# ...

# %% [markdown]
# Question 9: Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")

driver.get('https://www.imdb.com/list/ls095964455/')

driver.maximize_window()

Name=[i.text for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")] 

Year_span=[i.text for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")]

Genre=[i.text for i in driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[@class='genre']")]

Run_time=[i.text for i in driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[@class='runtime']")]

Ratings=[i.text for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[@class='ipl-rating-star__rating']")]

Votes=[i.text for i in driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[@name='nv']")]

# %%
TV_series=pd.DataFrame({"Name":Name,
                       "YEAR_SPAN":Year_span,
                       "Genre":Genre,
                       "Run TIME":Run_time,
                       "Rating":Ratings,
                       "Votes":Votes})
TV_series
# Out:
#                               Name    YEAR_SPAN                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run TIME Rating      Votes
# 0    57 min    9.2  1,883,831
# ...

# %% [markdown]
# Question 10: Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
driver=webdriver.Chrome(r"C:\Users\Piyush\Downloads\chromedriver_win32 (1)\chromedriver.exe")

driver.get('https://archive.ics.uci.edu/ml/index.php')

driver.maximize_window()
    
respository=driver.find_element_by_xpath("//span[@class='normal']/b/a")
respository.click()
details=[i.text for i in driver.find_elements_by_xpath("//table[@border='1']/tbody/tr/td")]
del details[:7]

Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]
j=0

while j<len(details):
    Dataset_name.append(details[j])
    j+=1
    Data_type.append(details[j])
    j+=1
    Task.append(details[j])
    j+=1
    Attribute_type.append(details[j])
    j+=1
    No_of_instances.append(details[j])
    j+=1
    No_of_attribute.append(details[j])
    j+=1
    Year.append(details[j])
    j+=1

# %%
Datasets=pd.DataFrame({"Dataset name":Dataset_name,
                      "Data type":Data_type,
                      "Task":Task,
                      "Attribute_type":Attribute_type,
                      "No of instances":No_of_instances,
                      "No of attribute":No_of_attribute,
                      "Year":Year})

Datasets
# Out:
#                            Dataset name      Data type                  Task  \
# 0                               Abalone  Multivariate        Classification
# 1                                 Adult  Multivariate        Classification
# 2                             Annealing  Multivariate        Classification
# 3          Anonymous Microsoft Web Data                 Recommender-Systems
# 4                            Arrhythmia  Multivariate        Classification
# ..                                  ...            ...                   ...
# 583    in-vehicle coupon recommendation  Multivariate        Classification
# 584                 Gait Classification  Multivariate        Classification
# 585           Wikipedia Math Essentials   Time-Series            Regression
# 586           Wikipedia Math Essentials   Time-Series            Regression
# 587        Synchronous Machine Data Set  Multivariate            Regression
#
# ...
